# %%
#处理 科目四驾考宝典1590题 科目一驾校宝典1853题
#先用word保存为docx

# %%
import docx
from docx import Document
from docx.oxml import OxmlElement
from docx.enum.dml import MSO_THEME_COLOR

# %%
# #用于检查
# pre=0
# for i in range(0,1594,1):
#     cur=int(data[i]['number'])
#     if cur-pre !=1 and cur!=45 and cur!=52 and cur!=2 and cur!=1205 and cur!=1567:
#         print(cur,pre,data[i]['question'])
#         break
#     pre=cur

# %%
# # 把有图片的题都注释上[有图片]  
# doc = Document(r'./OriginData/科目一驾校宝典1853题.docx')

# image_paragraphs = []
# for par in doc.paragraphs:
#     if 'graphicData' in par._p.xml:
#         image_paragraphs.append(par)
#         par.text=par.text+"[有图片]"
        
#         #break
# doc.save('科目一驾校宝典1853题_process_pic.docx') 


# #因为有些题缺失答案   在上面处理的基础上手动添加了答案 存到了：科目四驾考宝典1590题_process_pic.docx

# %%
#把全部文字弄成一个string
doc_path = './OriginData/科目一驾校宝典1853题 - 副本.docx'

def extract_text_from_docx(doc_path):
    doc = docx.Document(doc_path)

    text = ""
    for paragraph in doc.paragraphs:
        text += paragraph.text + "\n"

    for table in doc.tables:
        for row in table.rows:
            for cell in row.cells:
                for paragraph in cell.paragraphs:
                    text += paragraph.text + "\n"

    return text

# 提取文档中的所有文字
all_text = extract_text_from_docx(doc_path)

# %%
#正则

import re
import json


pattern = r"\d+[、.](.+?)\n(.*?)答案[：:]*(.+?)\n"
#pattern = r"(\d+)[、.](.+?)\n(.*?)/n*答案：(.+?)\s"
matches = re.findall(pattern, all_text,re.DOTALL)

print(matches)
data = []
for match in matches:
    question = match[0].strip()
    if match[1].strip():
        options = match[1].strip()
    else :
        options="A、正确\nB、错误"

    if match[2].strip()=="√" or match[2].strip()=="正确":
        answer="A"
    elif match[2].strip()=="×" or match[2].strip()=="错误" or match[2].strip()=="错":
        answer="B"
    else:
        answer = match[2].strip()

    pic_pattern=r"[有图片]"
    if re.findall(pic_pattern, options,re.DOTALL):
        pic_flag=True
    else:
        pic_flag=False

    
    answer_pattern=r"[^a-zA-Z]"
    if re.findall(answer_pattern, answer,re.DOTALL):
        explainnation = re.findall(r'[^a-zA-Z]+', answer)[0]
        answer=answer[0]
    else:
        explainnation=""

    question_data = {
        'question': question,
        'choose': options,
        'answer': answer,
        'picture':pic_flag,
        'explainnation':explainnation
    }

    data.append(question_data)

print(len(data))

# 将数据保存为JSON文件
with open('question_data.json', 'w', encoding='utf-8') as json_file:
    json.dump(data, json_file, ensure_ascii=False, indent=4)
# Out:
# [(' 驾驶机动车在道路上违反道路交通安全法的行为，属于什么行为？', 'A、违章行为\nB、违法行为\nC、过失行为\nD、违规行为\n', 'B'), (' 机动车驾驶人违法驾驶造成重大交通事故构成犯罪的，依法追究什么责任？', 'A、刑事责任\nB、民事责任\nC、经济责任\nD、直接责任\n', 'A'), (' 机动车驾驶人造成事故后逃逸构成犯罪的，吊销驾驶证且多长时间不得重新取得驾驶证？', 'A、5年内\nB、10年内\nC、终生\nD、20年内\n', 'C'), ('驾驶机动车违反道路交通安全法律法规发生交通事故属于交通违章行为。', '', '×'), ('驾驶机动车在道路上违反道路通行规定应当接受相应的处罚。', '', '√'), ('对未取得驾驶证驾驶机动车的，追究其法律责任。', '', '√'), ('对违法驾驶发生重大交通事故且构成犯罪的，不追究其刑事责任。', '', '×'), ('造成交通事故后逃逸且构成犯罪的驾驶人,将吊销驾驶证且终生不得重新取得驾驶证。', '', '√'), ('驾驶机动车在道路上违反交通安全法规的行为属于违法行为。', '', '√'), ('驾驶机动车应当随身携带哪种证件？', 'A、工作证\nB、驾驶证\nC、身份证\nD、职业资格证\n', 'B'), ('未取得驾驶证的学员在道路上学习驾驶技能，下列哪种做法是正确的？', 'A、使用所学车型的教练车由教练员随车指导\nB、使用所学车型的教练车单独驾驶学习\nC、使用私家车由教练员随车指导\nD、使用所学车型的教练车由非教练员的驾驶人随车指导\n', 'A'), ('机动车驾驶人初次申领驾驶证后的实习期是多长时间？', 'A、6个月\nB、12个月\nC、16个月\nD、18个月\n', 'B'), ('在实习期内驾驶机动车的，应当在车身后部粘贴或者悬挂哪种标志？', 'A、注意新手标志\nB、注意避让标志\nC、统一式样的实习标志\nD、注意车距标志\n', 'C'), ('以欺骗、贿赂等不正当手段取得驾驶证被依法撤销驾驶许可的，多长时间不得重新申请驾驶许可？', 'A、3年内\nB、终身\nC、1年内\nD、5年内\n', 'A'), ('驾驶人要按照驾驶证载明的准驾车型驾驶车辆。', '', '√'), ('上路行驶的机动车未随车携带身份证的，交通警察可依法扣留机动车。', '', '×'), ('上路行驶的机动车未放置检验合格标志的，交通警察可依法扣留机动车。', '', '√'), ('伪造、变造机动车驾驶证构成犯罪的将被依法追究刑事责任。', '', '√'), ('机动车驾驶人在实习期内驾驶机动车不得牵引挂车。', '', '√'), ('驾驶拼装机动车上路行驶的驾驶人，除按规定接受罚款外，还要受到哪种处理？', 'A、处10日以下拘留\nB、暂扣驾驶证\nC、吊销驾驶证\nD、追究刑事责任\n', 'C'), ('驾驶报废机动车上路行驶的驾驶人，除按规定罚款外，还要受到哪种处理？', 'A、撤销驾驶许可\nB、收缴驾驶证\nC、强制恢复车况\nD、吊销驾驶证\n', 'D'), ('对驾驶已达到报废标准的机动车上路行驶的驾驶人，会受到下列哪种处罚？', 'A、处15日以下拘留\nB、吊销机动车驾驶证\nC、处20以上200元以下罚款\nD、追究刑事责任\n', 'B'), ('对驾驶拼装机动车上路行驶的驾驶人，会受到下列哪种处罚？', 'A、处15日以下拘留\nB、依法追究刑事责任\nC、处200以上2000元以下罚款\nD、吊销机动车行驶证\n', 'C'), ('驾驶机动车上路前应当检查车辆安全技术性能。', '', '√'), ('不得驾驶具有安全隐患的机动车上道路行驶。', '', '√'), ('拼装的机动车只要认为安全就可以上路行驶。', '', '×'), ('已经达到报废标准的机动车经大修后可以上路行驶。', '', '×'), ('下列哪种证件是驾驶机动车上路行驶应当随车携带？', 'A、机动车登记证\nB、机动车保险单\nC、机动车行驶证\nD、出厂合格证明\n', 'C'), ('驾驶这种机动车上路行驶属于什么行为？', '[有图片]\nA、违规行为\nB、违章行为\nC、违法行为\nD、犯罪行为\n', 'C    '), ('下列哪种标志是驾驶机动车上路行驶应当在车上放置的标志？', 'A、产品合格标志\nB、保持车距标志\nC、提醒危险标志\nD、检验合格标志\n', 'D'), ('驾驶人在下列哪种情况下不能驾驶机动车？', 'A、饮酒后\nB、喝茶后\nC、喝咖啡后\nD、喝牛奶后\n', 'A'), ('这辆在道路上行驶的机动车有下列哪种违法行为？', '[有图片]\nA、逆向行驶\nB、未按规定悬挂号牌\nC、故意遮挡号牌\nD、占用非机动车道\n', 'C'), ('驾驶机动车上路行驶应当按规定悬挂号牌。', '', '√'), ('驾驶这种机动车上路行驶没有违法行为。', '[有图片]\n', '×'), ('服用国家管制的精神药品可以短途驾驶机动车。', '', '×'), ('饮酒后只要不影响驾驶操作可以短距离驾驶机动车。', '', '×'), (' 公安机关交通管理部门对驾驶人的交通违法行为除依法给予行政处罚外,实行下列哪种制度？', 'A、违法登记制度\nB、奖励里程制度\nC、累积记分制度\nD、强制报废制度\n', 'C'), ('道路交通安全违法行为累积记分的周期是多长时间？', 'A、3个月\nB、6个月\nC、12个月\nD、24个月\n', 'C'), ('公安机关交通管理部门对累积记分达到规定分值的驾驶人怎样处理？', 'A、依法追究刑事责任\nB、处15日以下拘留\nC、终生禁驾\nD、进行法律法规教育，重新考试\n', 'D'), ('驾驶人出现下列哪种情况，不得驾驶机动车？', 'A、驾驶证丢失、损毁\nB、驾驶证接近有效期\nC、记分达到10分\nD、记分达到6分\n', 'A'), ('驾驶人在驾驶证丢失后3个月内还可以驾驶机动车。', '', '×'), ('驾驶人持超过有效期的驾驶证可以在1年内驾驶机动车。', '', '×'), ('驾驶人的驾驶证损毁后不得驾驶机动车。', '', '√'), ('记分满12分的驾驶人拒不参加学习和考试的将被公告驾驶证停止使用。', '', '√'), ('驾驶人的机动车驾驶证被依法扣留、暂扣的情况下不得驾驶机动车。', '', '√'), ('前方路口这种信号灯亮表示什么意思？', '[有图片]\nA、路口警示\nB、禁止通行\nC、准许通行\nD、提醒注意\n', 'B'), ('前方路口这种信号灯亮表示什么意思？', '[有图片]\nA、路口警示\nB、加速直行\nC、加速左转\nD、禁止右转\n', 'A'), ('前方路口这种信号灯亮表示什么意思？', '[有图片]\nA、路口警示\nB、禁止通行\nC、准许通行\nD、提醒注意\n', 'C'), ('交通信号包括交通信号灯、交通标志、交通标线和交通警察的指挥。', '', '√'), ('交通标志和交通标线不属于交通信号。', '', '×'), ('交通信号灯由红灯、绿灯和黄灯组成。', '', '√'), ('道路交通标线分为指示标线、警告标线、禁止标线。', '', '√'), ('驾驶机动车在这种道路上如何通行？', '[有图片]\nA、在道路两边通行\nB、在道路中间通行\nC、实行分道通行\nD、可随意通行\n', 'B'), ('道路上划设这种标线的车道内允许下列哪类车辆通行？', '[有图片]\nA、出租车\nB、公务用车\nC、公交车\nD、私家车\n', 'C'), ('驾驶机动车在路口遇到这种情况如何行驶？', '[有图片]\nA、可以向右转弯\nB、靠右侧直行\nC、遵守交通信号灯\nD、停车等待\n', 'D'), ('有这种信号灯的路口允许机动车如何行驶？', '[有图片]\nA、向左转弯\nB、直行通过\nC、向右转弯\nD、停车等待\n', 'C'), ('遇到这种情况的路口怎样通过？', '[有图片]\nA、左转弯加速通过\nB、加速直行通过\nC、右转弯加速通过\nD、确认安全后通过\n', 'D'), ('这段道路红车所在车道是什么车道？', '[有图片]\nA、快速车道\nB、慢速车道\nC、专用车道\nD、应急车道\n', 'A'), ('机动车在道路上变更车道需要注意什么？', 'A、尽快加速进入左侧车道\nB、不能影响其他车辆正常行驶\nC、进入左侧车道时适当减速\nD、开启转向灯迅速向左转向\n', 'B'), ('在这种情况下可以借右侧公交车道超车。', '[有图片]\n', '×'), ('在路口遇有交通信号灯和交通警察指挥不一致时，按照交通信号灯通行。', '', '×'), ('在这种情况下可加速通过交叉路口。', '[有图片]\n', '×'), ('在路口这个位置时可以加速通过路口。', '[有图片]\n', '×'), ('驾驶机动车不能进入红色叉形灯或者红色箭头灯亮的车道。', '', '√'), ('在这段路的最高时速为每小时50公里。', '[有图片]\n', '×'), ('这辆红色轿车变更车道的方法和路线是正确的。', '[有图片]\n', '×'), ('驾驶机动车在道路上向左变更车道时如何使用灯光？', 'A、不用开启转向灯\nB、提前开启右转向灯\nC、提前开启左转 ...
# 1847

# %%
# 过滤掉有图片的
with open('question_data.json') as file:
    data = json.load(file)
filtered_data=[item for item in data if not item['picture']]
for item in data:
    del item["picture"]

# 将数据保存为JSON文件
with open('科目一驾校宝典1853题.json', 'w', encoding='utf-8') as json_file:
    json.dump(filtered_data, json_file, ensure_ascii=False, indent=4)
